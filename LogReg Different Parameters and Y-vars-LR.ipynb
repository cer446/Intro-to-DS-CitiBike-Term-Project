# %%
# Load data
import json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn.preprocessing
from sklearn.linear_model import LogisticRegression
import project_env
from imp import reload
import math
import os
import run_logreg
import project_env
from sklearn.metrics import precision_recall_curve

reload(project_env)
reload(run_logreg)

# %matplotlib inline

# %% [markdown]
# **The `project_env` package**
#
# I wrote this python package so loading and working with data is quicker and easier. There are several convenience methods:
# * `load_split_bucket(station_id)` - Load data for a bike station that's already pre-split into train, dev and test. Includes doing data cleaning and thresholding. The output is a dictionary:
# ```
#   {
#     'train': (DataFrame, Series),
#     'dev': (DataFrame, Series),
#     'test': (DataFrame, Series)
#   }
# ```
#   Each `(DataFrame, Series)` tuple is the feature values and target variables, respectively.
# * `merge_training(split, df)` - Given two outputs of `load()`, append the training set of the second argument to the training set of the first. This is useful when trying to load data from multiple stations, but testing on one station only.
# * `binarize(data, target)` - Given output of `load()` and either 1 or -1, binarize the target variable to 0 or 1. Whatever class is in the second argument will become '1' in the new data.

# %% [markdown]
# **The `run_logreg` package**
#
# We wrote this python package so running many logistic regression models with different parameters is cleaner and easier. Here are the methods included:
#
# * `do_logreg` - Takes the result of split_data and performs a logistic regression given the input parameters. It takes a parameters called "squares" that will perform some basic feature engineering by squaring some of the variables, a penalty function (l1 or l2, defaults to l2), and a c parameter (defaults to 100,000).
#
# * `distance` - Calculates the distance betweent two stations, based on the distance formula
#
# * `closest_stations` - Identifies the stations closest to the input station, using the `distance` function
#
# * `add_closest_stations` - Takes split_data for one station and its station_id, splits, merges the closest stations' data and binarizes all
#
# * `format_plot` - Formats the plot according to the desired target_recall and whether this is a plot of empty or full

# %% [markdown]
# ### Logistic Regression Model

# %%
data = project_env.load_split_bucket(519, target='y_60m', log=False)
print('done loading')
# Out:
# done loading

# %%
class Logistic_Regression_Specs():
    def __init__(self, split_data, stationid, target, empty=True, squares=False, num_append=0, C=1e5, penalty='l2'):
        self.stationid = stationid
        self.target = target
        self.split_data = split_data
        self.empty = empty
        self.squares = squares
        self.num_append = num_append
        self.penalty = penalty
        self.C = C

# %%
def construct_key(spec):
    key = ''
    if spec.target != 'y_60m':
        key = key + spec.target + ' '
    if spec.squares == True:
        key = key + 'squares; '
    if spec.num_append > 0:
        key = key + 'append: ' + str(spec.num_append) + '; '
    key = key + 'penalty: ' + spec.penalty + '; '
    key = key + 'c: ' + str(spec.C) + '; '
    return key

# %%
def run_models(list_of_specs):
    '''Creates a dictionary of models based on list of specs objects'''
    
    logregs = {}
    scalers = {}
    predictions = {}
    specs = {}
    
    for spec in list_of_specs:
        logregs[construct_key(spec)], scalers[construct_key(spec)], predictions[construct_key(spec)] = run_logreg.do_logreg(spec, plot = False) 
        specs[(construct_key(spec))] = spec
    return logregs, scalers, predictions, specs

# %%
def pr_curve(predictions, true_value, target_recall=0.95):
    curve = precision_recall_curve(true_value, predictions)
    precision, recall, thresholds = curve
    mp, mr, mt = project_env.max_precision_for_recall(curve, target_recall=target_recall)
    return mp, mr, mt

target_vars = ['y_10m','y_15m','y_30m','y_45m','y_60m','y_90m','y_120m']
c_list = [.01,.1,1,10,100,1000]
penalties = ['l1','l2']
target_list = {}

df_dict = {}

#Returns a dictionary within a dictionary.  Outer dictionary is keyed on target var. inner dictionary keyed on a 
# "model number" and contains the specs of the model as well as a list of the [mp,mr,mt]
# You can probably used this to find the max MR for each target variable
for target in target_vars:
    data = project_env.load_split_bucket(519, target=target, log=False)
    data_empty = data_binarized = project_env.binarize(data, -1)
    gold_labels = data_empty['dev'][1]
    models = {}
    model_id=0
    rows = 2*3*int(len(c_list))*int(len(penalties))
    
    
    columns=['specs', 'mp','mr','mt']
    df_dict[target] = pd.DataFrame(data=np.zeros((rows,len(columns))), \
                                 columns=columns) 
    
    
    
    for squares in [True, False]:
        for num_append in [0,1,10]:
            for c in c_list:
                for penalty in penalties:

                    spec = Logistic_Regression_Specs(data, 519, target, empty=True, squares=squares, num_append=num_append,C=c,penalty=penalty)
                    
                    
                    
                    logregs_e, scalers_e, predictions_e = run_logreg.do_logreg(spec, plot = False)
                    #print(predictions_e)
                    mp, mr, mt = pr_curve(predictions_e,gold_labels,target_recall=0.95)
                
                    df_dict[target]['specs'].loc[model_id] = [target,squares,num_append,c,penalty]
                    df_dict[target]['mp'].loc[model_id] = mp
                    df_dict[target]['mr'].loc[model_id] = mr
                    df_dict[target]['mt'].loc[model_id] = mt
                    #model_specs = [target,squares,num_append,c,penalty]
                    #models.setdefault(model_id,[]).append([model_specs,mp,mr,mt])
                    model_id = model_id + 1 
    
    #target_list.setdefault(target,[]).append(models)
# Out:
# X shape: (4289, 44)
# Evaluating on dev set of 1002 examples
# Accuracy: 0.87624750499
# [[512 102]
#  [ 22 366]]
# X shape: (4289, 44)
# Evaluating on dev set of 1002 examples
# Accuracy: 0.885229540918
# [[548  66]
#  [ 49 339]]
# /Users/Lisa/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:140: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# X shape: (4289, 44)
# Evaluating on dev set of 1002 examples
# Accuracy: 0.898203592814
# [[551  63]
#  [ 39 349]]
# X shape: (4289, 44)
# Evaluating on dev set of 1002 examples
# Accuracy: 0.894211576846
# [[551  63]
#  [ 43 345]]
# X shape: (4289, 44)
# Evaluating on dev set of 1002 examples
# Accuracy: 0.88622754491
# [[537  77]
#  [ 37 351]]
# X shape: (4289, 44)
# Evaluating on dev set of 1002 examples
# Accuracy: 0.88622754491
# [[535  79]
#  [ 35 353]]
# X shape: (4289, 44)
# Evaluating on dev set of 1002 examples
# Accuracy: 0.878243512974
# [[531  83]
#  [ 39 349]]
# X shape: (4289, 44)
# Evaluating on dev set of 1002 examples
# Accuracy: 0.878243512974
# [[531  83]
#  [ 39 349]]
# X shape: (4289, 44)
# /Users/Lisa/anaconda3/lib/python3.5/site-packages/sklearn/linear_model/base.py:352: RuntimeWarning: overflow encountered in exp
#   np.exp(prob, prob)
# Evaluating on dev set of 1002 examples
# Accuracy: 0.877245508982
# [[530  84]
#  [ 39 349]]
# X shape: (4289, 44)
# Evaluating on dev set of 1002 examples
# Accuracy: 0.87624750499
# [[529  85]
#  [ 39 349]]
# X shape: (4289, 44)
# Evaluating on dev set of 1002 examples
# Accuracy: 0.877245508982
# [[530  84]
#  [ 39 349]]
# X shape: (4289, 44)
# Evaluating on dev set of 1002 examples
# Accuracy: 0.87624750499
# [[528  86]
#  [ 38 350]]
# X shape: (7463, 44)
# Evaluating on dev set of 1002 examples
# Accuracy: 0.892215568862
# [[535  79]
#  [ 29 359]]
# X shape: (7463, 44)
# Evaluating on dev set of 1002 examples
# Accuracy: 0.877245508982
# [[532  82]
#  [ 41 347]]
# X shape: (7463, 44)
# Evaluating on dev set of 1002 examples
# Accuracy: 0.895209580838
# [[546  68]
#  [ 37 351]]
# X shape: (7463, 44)
# Evaluating on dev set of 1002 examples
# Accuracy: 0.895209580838
# [[549  65]
#  [ 40 348]]
# X shape: (7463, 44)
# Evaluating on dev set of 1002 examples
# Accuracy: 0.899201596806
# [[550  64]
#  [ 37 351]]
# X shape: (7463, 44)
# Evaluating on dev set of 1002 examples
# Accuracy: 0.895209580838
# [[548  66]
#  [ 39 349]]
# X shape: (7463, 44)
# Evaluating on dev set of 1002 examples
# Accuracy: 0.895209580838
# [[548  66]
#  [ 39 349]]
# X shape: (7463, 44)
# Evaluating on dev set of 1002 examples
# Accuracy: 0.894211576846
# [[547  67]
#  [ 39 349]]
# X shape: (7463, 44)
# Evaluating on dev set of 1002 examples
# Accuracy: 0.892215568862
# [[546  68]
#  [ 40 348]]
# X shape: (7463, 44)
# Evaluating on dev set of 1002 examples
# Accuracy: 0.892215568862
# [[546  68]
#  [ 40 348]]
# X shape: (7463, 44)
# Evaluating on dev set of 1002 examples
# Accuracy: 0.892215568862
# [[546  68]
#  [ 40 348]]
# X shape: (7463, 44)
# Evaluating on dev set of 1002 examples
# Accuracy: 0.89121756487
# [[545  69]
#  [ 40 348]]
# X shape: (37617, 44)
# Evaluating on dev set of 1002 examples
# Accuracy: 0.907185628743
# [[552  62]
#  [ 31 357]]
# X shape: (37617, 44)
# Evaluating on dev set of 1002 examples
# Accuracy: 0.89620758483
# [[559  55]
#  [ 49 339]]
# X shape: (37617, 44)
# Evaluating on dev set of 1002 examples
# Accuracy: 0.908183632735
# [[551  63]
#  [ 29 359]]
# X shape: (37617, 44)
# Evaluating on dev set of 1002 examples
# Accuracy: 0.909181636727
# [[551  63]
#  [ 28 360]]
# X shape: (37617, 44)
# Evaluating on dev set of 1002 examples
# Accuracy: 0.903193612774
# [[547  67]
#  [ 30 358]]
# X shape: (37617, 44)
# Evaluating on dev set of 1002 examples
# Accuracy: 0.903193612774
# [[545  69]
#  [ 28 360]]
# X shape: (37617, 44)
# Evaluating on dev set of 1002 examples
# Accuracy: 0.904191616766
# [[547  67]
#  [ 29 359]]
# X shape: (37617, 44)
# Evaluating on dev set of 1002 examples
# Accuracy: 0.90119760479
# [[544  70]
#  [ 29 359]]
# X shape: (37617, 44)
# Evaluating on dev set of 1002 examples
# Accuracy: 0.903193612774
# [[546  68]
#  [ 29 359]]
# X shape: (37617, 44)
# Evaluating on dev set of 1002 examples
# Accuracy: 0.90119760479
# [[544  70]
#  [ 29 359]]
# X shape: (37617, 44)
# Evaluating on dev set of 1002 examples
# Accuracy: 0.904191616766
# [[546  68]
#  [ 28 360]]
# X shape: (37617, 44)
# Evaluating on dev set of 1002 examples
# Accuracy: 0.90119760479
# [[544  70]
#  [ 29 359]]
# X shape: (4289, 22)
# Evaluating on dev set of 1002 examples
# Accuracy: 0.880239520958
# [[502 112]
#  [  8 380]]
# X shape: (4289, 22)
# Evaluating on dev set of 1002 examples
# Accuracy: 0.858283433134
# [[478 136]
#  [  6 382]]
# X shape: (4289, 22)
# Evaluating on dev set of 1002 examples
# Accuracy: 0.904191616766
# [[541  73]
#  [ 23 365]]
# X shape: (4289, 22)
# Evaluating on dev set of 1002 examples
# Accuracy: 0.87624750499
# [[517  97]
#  [ 27 361]]
# X shape: (4289, 22)
# Evaluating on dev set of 1002 examples
# Accuracy: 0.89620758483
# [[544  70]
#  [ 34 354]]
# X shape: (4289, 22)
# Evaluating on dev set of 1002 examples
# Accuracy: 0.893213572854
# [[541  73]
#  [ 34 354]]
# X shape: (4289, 22)
# Evaluating on dev set of 1002 examples
# Accuracy: 0.89620758483
# [[546  68]
#  [ 36 352]]
# X shape: (4289, 22)
# Evaluating on dev set of 1002 examples
# Accuracy: 0.89620758483
# [[546  68]
#  [ 36 352]]
# X shape: (4289, 22)
# Evaluating on dev set of 1002 examples
# Accuracy: 0.89620758483
# [[546  68]
#  [ 36 352]]
# X shape: (4289, 22)
# Evaluating on dev set of 1002 examples
# Accuracy: 0.89620758483
# [[546  68]
#  [ 36 352]]
# X shape: (4289, 22)
# Evaluating on dev set of 1002 examples
# Accuracy: 0.89620758483
# [[546  68]
#  [ 36 352]]
# X shape: (4289, 22)
# Evaluating on dev set of 1002 examples
# Accuracy: 0.89620758483
# [[546  68]
#  [ 36 352]]
# X shape: (7463, 22)
# Evaluating on dev set of 1002 examples
# Accuracy: 0.898203592814
# [[530  84]
#  [ 18 370]]
# X shape: (7463, 22)
# Evaluating on dev set of 1002 examples
# Accuracy: 0.849301397206
# [[481 133]
#  [ 18 370]]
# X shape: (7463, 22)
# Evaluating on dev set of 1002 examples
# Accuracy: 0.907185628743
# [[545  69]
#  [ 24 364]]
# X shape: (7463, 22)
# Evaluating on dev set of 1002 examples
# Accuracy: 0.88622754491
# [[527  87]
#  [ 27 361]]
# X shape: (7463, 22)
# Evaluating on dev set of 1002 examples
# Accuracy: 0.89620758483
# [[545  69]
#  [ 35 353]]
# X shape: (7463, 22)
# Evaluating on dev set of 1002 examples
# Accuracy: 0.894211576846
# [[543  71]
#  [ 35 353]]
# X shape: (7463, 22)
# Evaluating on dev set of 1002 examples
# Accuracy: 0.895209580838
# [[545  69]
#  [ 36 352]]
# X shape: (7463, 22)
# Evaluating on dev set of 1002 examples
# Accuracy: 0.895209580838
# [[545  69]
#  [ 36 352]]
# X shape: (7463, 22)
# Evaluating on dev set of 1002 examples
# Accuracy: 0.895209580838
# [[545  69]
#  [ 36 352]]
# X shape: (7463, 22)
# Evaluating on dev set of 1002 examples
# Accuracy: 0.895209580838
# [[545  69]
#  [ 36 352]]
# X shape: (7463, 22)
# Evaluating on dev set of 1002 examples
# Accuracy: 0.895209580838
# [[545  69]
#  [ 36 352]]
# X shape: (7463, 22)
# Evaluating on dev set of 1002 examples
# Accuracy: 0.895209580838
# [[545  69]
#  [ 36 352]]
# X shape: (37617, 22)
# Evaluating on dev set of 1002 examples
# Accuracy: 0.908183632735
# [[550  64]
#  [ 28 360]]
# X shape: (37617, 22)
# Evaluating on dev set of 1002 examples
# Accuracy: 0.899201596806
# [[527  87]
#  [ 14 374]]
# X shape: (37617, 22)
# Evaluating on dev set of 1002 examples
# Accuracy: 0.908183632735
# [[550  64]
#  [ 28 360]]
# X shape: (37617, 22)
# Evaluating on dev set of 1002 examples
# Accuracy: 0.904191616766
# [[543  71]
#  [ 25 363]]
# X shape: (37617, 22)
# Evaluating on dev set of 1002 examples
# Accuracy: 0.908183632735
# [[550  64]
#  [ 28 360]]
# X shape: (37617, 22)
# Evaluating on dev set of 1002 examples
# Accuracy: 0.910179640719
# [[550  64]
#  [ 26 362]]
# X shape: (37617, 22)
# Evaluating on dev set of 1002 examples
# Accuracy: 0.909181636727
# [[552  62]
#  [ 29 359]]
# X shape: (37617, 22)
# Evaluating on dev set of 1002 examples
# Accuracy: 0.909181636727
# [[552  62]
#  [ 29 359]]
# X shape: (37617, 22)
# Evaluating on dev set of 1002 examples
# Accuracy: 0.909181636727
# [[552  62]
#  [ 29 359]]
# X shape: (37617, 22)
# Evaluating on dev set of 1002 examples
# Accuracy: 0.910179640719
# [[553  61]
#  [ 29 359]]
# X shape: (37617, 22)
# Evaluating on dev set of 1002 examples
# Accuracy: 0.909181636727
# [[552  62]
#  [ 29 359]]
# X shape: (37617, 22)
# Evaluating on dev set of 1002 examples
# Accuracy: 0.910179640719
# [[553  61]
#  [ 29 359]]
# X shape: (4257, 44)
# Evaluating on dev set of 993 examples
# Accuracy: 0.851963746224
# [[488 109]
#  [ 38 358]]
# X shape: (4257, 44)
# Evaluating on dev set of 993 examples
# Accuracy: 0.858006042296
# [[506  91]
#  [ 50 346]]
# X shape: (4257, 44)
# Evaluating on dev set of 993 examples
# Accuracy: 0.890231621349
# [[518  79]
#  [ 30 366]]
# X shape: (4257, 44)
# Evaluating on dev set of 993 examples
# Accuracy: 0.867069486405
# [[500  97]
#  [ 35 361]]
# X shape: (4257, 44)
# Evaluating on dev set of 993 examples
# Accuracy: 0.85498489426
# [[480 117]
#  [ 27 369]]
# X shape: (4257, 44)
# Evaluating on dev set of 993 examples
# Accuracy: 0.853977844914
# [[481 116]
#  [ 29 367]]
# X shape: (4257, 44)
# Evaluating on dev set of 993 examples
# Accuracy: 0.846928499496
# [[472 125]
#  [ 27 369]]
# X shape: (4257, 44)
# Evaluating on dev set of 993 examples
# Accuracy: 0.845921450151
# [[472 125]
#  [ 28 368]]
# X shape: (4257, 44)
# Evaluating on dev set of 993 examples
# Accuracy: 0.84390735146
# [[470 127]
#  [ 28 368]]
# X shape: (4257, 44)
# Evaluating on dev set of 993 examples
# Accuracy: 0.84390735146
# [[470 127]
#  [ 28 368]]
# X shape: (4257, 44)
# Evaluating on dev set of 993 examples
# Accuracy: 0.844914400806
# [[470 127]
#  [ 27 369]]
# X shape: (4257, 44)
# Evaluating on dev set of 993 examples
# Accuracy: 0.84390735146
# [[470 127]
#  [ 28 368]]
# X shape: (7385, 44)
# Evaluating on dev set of 993 examples
# Accuracy: 0.87915407855
# [[512  85]
#  [ 35 361]]
# X shape: (7385, 44)
# Evaluating on dev set of 993 examples
# Accuracy: 0.85498489426
# [[497 100]
#  [ 44 352]]
# X shape: (7385, 44)
# Evaluating on dev set of 993 examples
# Accuracy: 0.889224572004
# [[523  74]
#  [ 36 360]]
# X shape: (7385, 44)
# Evaluating on dev set of 993 examples
# Accuracy: 0.870090634441
# [[509  88]
#  [ 41 355]]
# X shape: (7385, 44)
# Evaluating on dev set of 993 examples
# Accuracy: 0.875125881168
# [[507  90]
#  [ 34 362]]
# X shape: (7385, 44)
# Evaluating on dev set of 993 examples
# Accuracy: 0.874118831823
# [[505  92]
#  [ 33 363]]
# X shape: (7385, 44)
# Evaluating on dev set of 993 examples
# Accuracy: 0.877139979859
# [[506  91]
#  [ 31 365]]
# X shape: (7385, 44)
# Evaluating on dev set of 993 examples
# Accuracy: 0.877139979859
# [[506  91]
#  [ 31 365]]
# X shape: (7385, 44)
# Evaluating on dev set of 993 examples
# Accuracy: 0.875125881168
# [[504  93]
#  [ 31 365]]
# X shape: (7385, 44)
# Evaluating on dev set of 993 examples
# Accuracy: 0.873111782477
# [[503  94]
#  [ 32 364]]
# X shape: (7385, 44)
# Evaluating on dev set of 993 examples
# Accuracy: 0.876132930514
# [[505  92]
#  [ 31 365]]
# X shape: (7385, 44)
# Evaluating on dev set of 993 examples
# Accuracy: 0.873111782477
# [[503  94]
#  [ 32 364]]
# X shape: (37469, 44)
# Evaluating on dev set of 993 examples
# Accuracy: 0.896273917422
# [[526  71]
#  [ 32 364]]
# X shape: (37469, 44)
# Evaluating on dev set of 993 examples
# Accuracy: 0.880161127895
# [[526  71]
#  [ 48 348]]
# X shape: (37469, 44)
# Evaluating on dev set of 993 examples
# Accuracy: 0.899295065458
# [[526  71]
#  [ 29 367]]
# X shape: (37469, 44)
# Evaluating on dev set of 993 examples
# Accuracy: 0.899295065458
# [[525  72]
#  [ 28 368]]
# X shape: (37469, 44)
# Evaluating on dev set of 993 examples
# Accuracy: 0.901309164149
# [[523  74]
#  [ 24 372]]
# X shape: (37469, 44)
# Evaluating on dev set of 993 examples
# Accuracy: 0.902316213494
# [[523  74]
#  [ 23 373]]
# X shape: (37469, 44)
# Evaluating on dev set of 993 examples
# Accuracy: 0.902316213494
# [[523  74]
#  [ 23 373]]
# X shape: (37469, 44)
# Evaluating on dev set of 993 examples
# Accuracy: 0.900302114804
# [[521  76]
#  [ 23 373]]
# X shape: (37469, 44)
# Evaluating on dev set of 993 examples
# Accuracy: 0.902316213494
# [[523  74]
#  [ 23 373]]
# X shape: (37469, 44)
# Evaluating on dev set of 993 examples
# Accuracy: 0.899295065458
# [[521  76]
#  [ 24 372]]
# X shape: (37469, 44)
# Evaluating on dev set of 993 examples
# Accuracy: 0.901309164149
# [[523  74]
#  [ 24 372]]
# X shape: (37469, 44)
# Evaluating on dev set of 993 examples
# Accuracy: 0.899295065458
# [[521  76]
#  [ 24 372]]
# X shape: (4257, 22)
# Evaluating on dev set of 993 examples
# Accuracy: 0.867069486405
# [[478 119]
#  [ 13 383]]
# X shape: (4257, 22)
# Evaluating on dev set of 993 examples
# Accuracy: 0.832829808661
# [[450 147]
#  [ 19 377]]
# X shape: (4257, 22)
# Evaluating on dev set of 993 examples
# Accuracy: 0.886203423968
# [[506  91]
#  [ 22 374]]
# X shape: (4257, 22)
# Evaluating on dev set of 993 examples
# Accuracy: 0.877139979859
# [[504  93]
#  [ 29 367]]
# X shape: (4257, 22)
# Evaluating on dev set of 993 examples
# Accuracy: 0.887210473313
# [[516  81]
#  [ 31 365]]
# X shape: (4257, 22)
# Evaluating on dev set of 993 examples
# Accuracy: 0.887210473313
# [[515  82]
#  [ 30 366]]
# X shape: (4257, 22)
# Evaluating on dev set of 993 examples
# Accuracy: 0.887210473313
# [[518  79]
#  [ 33 363]]
# X shape: (4257, 22)
# Evaluating on dev set of 993 examples
# Accuracy: 0.886203423968
# [[517  80]
#  [ 33 363]]
# X shape: (4257, 22)
# Evaluating on dev set of 993 examples
# Accuracy: 0.884189325277
# [[517  80]
#  [ 35 361]]
# X shape: (4257, 22)
# Evaluating on dev set of 993 examples
# Accuracy: 0.883182275932
# [[516  81]
#  [ 35 361]]
# X shape: (4257, 22)
# Evaluating on dev set of 993 examples
# Accuracy: 0.884189325277
# [[517  80]
#  [ 35 361]]
# X shape: (4257, 22)
# Evaluating on dev set of 993 examples
# Accuracy: 0.883182275932
# [[516  81]
#  [ 35 361]]
# X shape: (7385, 22)
# Evaluating on dev set of 993 examples
# Accuracy: 0.889224572004
# [[508  89]
#  [ 21 375]]
# X shape: (7385, 22)
# Evaluating on dev set of 993 examples
# Accuracy: 0.84390735146
# [[465 132]
#  [ 23 373]]
# X shape: (7385, 22)
# Evaluating on dev set of 993 examples
# Accuracy: 0.890231621349
# [[519  78]
#  [ 31 365]]
# X shape: (7385, 22)
# Evaluating on dev set of 993 examples
# Accuracy: 0.877139979859
# [[503  94]
#  [ 28 368]]
# X shape: (7385, 22)
# Evaluating on dev set of 993 examples
# Accuracy: 0.888217522659
# [[520  77]
#  [ 34 362]]
# X shape: (7385, 22)
# Evaluating on dev set of 993 examples
# Accuracy: 0.885196374622
# [[517  80]
#  [ 34 362]]
# X shape: (7385, 22)
# Evaluating on dev set of 993 examples
# Accuracy: 0.889224572004
# [[521  76]
#  [ 34 362]]
# X shape: (7385, 22)
# Evaluating on dev set of 993 examples
# Accuracy: 0.889224572004
# [[521  76]
#  [ 34 362]]
# X shape: (7385, 22)
# Evaluating on dev set of 993 examples
# Accuracy: 0.890231621349
# [[522  75]
#  [ 34 362]]
# X shape: (7385, 22)
# Evaluating on dev set of 993 examples
# Accuracy: 0.890231621349
# [[522  75]
#  [ 34 362]]
# X shape: (7385, 22)
# Evaluating on dev set of 993 examples
# Accuracy: 0.890231621349
# [[522  75]
#  [ 34 362]]
# X shape: (7385, 22)
# Evaluating on dev set of 993 examples
# Accuracy: 0.890231621349
# [[522  75]
#  [ 34 362]]
# X shape: (37469, 22)
# Evaluating on dev set of 993 examples
# Accuracy: 0.896273917422
# [[523  74]
#  [ 29 367]]
# X shape: (37469, 22)
# Evaluating on dev set of 993 examples
# Accuracy: 0.896273917422
# [[509  88]
#  [ 15 381]]
# X shape: (37469, 22)
# Evaluating on dev set of 993 examples
# Accuracy: 0.899295065458
# [[525  72]
#  [ 28 368]]
# X shape: (37469, 22)
# Evaluating on dev set of 993 examples
# Accuracy: 0.899295065458
# [[522  75]
#  [ 25 371]]
# X shape: (37469, 22)
# Evaluating on dev set of 993 examples
# Accuracy: 0.899295065458
# [[525  72]
#  [ 28 368]]
# X shape: (37469, 22)
# Evaluating on dev set of 993 examples
# Accuracy: 0.899295065458
# [[525  72]
#  [ 28 368]]
# X shape: (37469, 22)
# Evaluating on dev set of 993 examples
# Accuracy: 0.900302114804
# [[526  71]
#  [ 28 368]]
# X shape: (37469, 22)
# Evaluating on dev set of 993 examples
# Accuracy: 0.900302114804
# [[526  71]
#  [ 28 368]]
# X shape: (37469, 22)
# Evaluating on dev set of 993 examples
# Accuracy: 0.900302114804
# [[526  71]
#  [ 28 368]]
# X shape: (37469, 22)
# Evaluating on dev set of 993 examples
# Accuracy: 0.900302114804
# [[526  71]
#  [ 28 368]]
# X shape: (37469, 22)
# Evaluating on dev set of 993 examples
# Accuracy: 0.900302114804
# [[526  71]
#  [ 28 368]]
# X shape: (37469, 22)
# Evaluating on dev set of 993 examples
# Accuracy: 0.900302114804
# [[526  71]
#  [ 28 368]]
# X shape: (4298, 44)
# Evaluating on dev set of 988 examples
# Accuracy: 0.832995951417
# [[481 120]
#  [ 45 342]]
# X shape: (4298, 44)
# Evaluating on dev set of 988 examples
# Accuracy: 0.838056680162
# [[491 110]
#  [ 50 337]]
# X shape: (4298, 44)
# Evaluating on dev set of 988 examples
# Accuracy: 0.851214574899
# [[491 110]
#  [ 37 350]]
# X shape: (4298, 44)
# Evaluating on dev set of 988 examples
# Accuracy: 0.831983805668
# [[473 128]
#  [ 38 349]]
# X shape: (4298, 44)
# Evaluating on dev set of 988 examples
# Accuracy: 0.80971659919
# [[443 158]
#  [ 30 357]]
# X shape: (4298, 44)
# Evaluating on dev set of 988 examples
# Accuracy: 0.806680161943
# [[439 162]
#  [ 29 358]]
# X shape: (4298, 44)
# Evaluating on dev set of 988 examples
# Accuracy: 0.803643724696
# [[434 167]
#  [ 27 360]]
# X shape: (4298, 44)
# Evaluating on dev set of 988 examples
# Accuracy: 0.7995951417
# [[430 171]
#  [ 27 360]]
# X shape: (4298, 44)
# Evaluating on dev set of 988 examples
# Accuracy: 0.7995951417
# [[429 172]
#  [ 26 361]]
# X shape: (4298, 44)
# Evaluating on dev set of 988 examples
# Accuracy: 0.797570850202
# [[428 173]
#  [ 27 360]]
# X shape: (4298, 44)
# Evaluating on dev set of 988 examples
# Accuracy: 0.7995951417
# [[429 172]
#  [ 26 361]]
# X shape: (4298, 44)
# Evaluating on dev set of 988 examples
# Accuracy: 0.7995951417
# [[428 173]
#  [ 25 362]]
# X shape: (7425, 44)
# Evaluating on dev set of 988 examples
# Accuracy: 0.837044534413
# [[487 114]
#  [ 47 340]]
# X shape: (7425, 44)
# Evaluating on dev set of 988 examples
# Accuracy: 0.817813765182
# [[472 129]
#  [ 51 336]]
# X shape: (7425, 44)
# Evaluating on dev set of 988 examples
# Accuracy: 0.835020242915
# [[487 114]
#  [ 49 338]]
# X shape: (7425, 44)
# Evaluating on dev set of 988 examples
# Accuracy: 0.816801619433
# [[469 132]
#  [ 49 338]]
# X shape: (7425, 44)
# Evaluating on dev set of 988 examples
# Accuracy: 0.814777327935
# [[463 138]
#  [ 45 342]]
# X shape: (7425, 44)
# Evaluating on dev set of 988 examples
# Accuracy: 0.811740890688
# [[459 142]
#  [ 44 343]]
# X shape: (7425, 44)
# Evaluating on dev set of 988 examples
# Accuracy: 0.810728744939
# [[457 144]
#  [ 43 344]]
# X shape: (7425, 44)
# Evaluating on dev set of 988 examples
# Accuracy: 0.80971659919
# [[456 145]
#  [ 43 344]]
# X shape: (7425, 44)
# Evaluating on dev set of 988 examples
# Accuracy: 0.810728744939
# [[457 144]
#  [ 43 344]]
# X shape: (7425, 44)
# Evaluating on dev set of 988 examples
# Accuracy: 0.810728744939
# [[457 144]
#  [ 43 344]]
# X shape: (7425, 44)
# Evaluating on dev set of 988 examples
# Accuracy: 0.810728744939
# [[457 144]
#  [ 43 344]]
# X shape: (7425, 44)
# Evaluating on dev set of 988 examples
# Accuracy: 0.812753036437
# [[458 143]
#  [ 42 345]]
# X shape: (37336, 44)
# Evaluating on dev set of 988 examples
# Accuracy: 0.861336032389
# [[514  87]
#  [ 50 337]]
# X shape: (37336, 44)
# Evaluating on dev set of 988 examples
# Accuracy: 0.849190283401
# [[507  94]
#  [ 55 332]]
# X shape: (37336, 44)
# Evaluating on dev set of 988 examples
# Accuracy: 0.842105263158
# [[495 106]
#  [ 50 337]]
# X shape: (37336, 44)
# Evaluating on dev set of 988 examples
# Accuracy: 0.841093117409
# [[492 109]
#  [ 48 339]]
# X shape: (37336, 44)
# Evaluating on dev set of 988 examples
# Accuracy: 0.844129554656
# [[490 111]
#  [ 43 344]]
# X shape: (37336, 44)
# Evaluating on dev set of 988 examples
# Accuracy: 0.843117408907
# [[489 112]
#  [ 43 344]]
# X shape: (37336, 44)
# Evaluating on dev set of 988 examples
# Accuracy: 0.84008097166
# [[489 112]
#  [ 46 341]]
# X shape: (37336, 44)
# Evaluating on dev set of 988 examples
# Accuracy: 0.84008097166
# [[489 112]
#  [ 46 341]]
# X shape: (37336, 44)
# Evaluating on dev set of 988 examples
# Accuracy: 0.84008097166
# [[489 112]
#  [ 46 341]]
# X shape: (37336, 44)
# Evaluating on dev set of 988 examples
# Accuracy: 0.841093117409
# [[490 111]
#  [ 46 341]]
# X shape: (37336, 44)
# Evaluating on dev set of 988 examples
# Accuracy: 0.841093117409
# [[488 113]
#  [ 44 343]]
# X shape: (37336, 44)
# Evaluating on dev set of 988 examples
# Accuracy: 0.841093117409
# [[490 111]
#  [ 46 341]]
# X shape: (4298, 22)
# Evaluating on dev set of 988 examples
# Accuracy: 0.830971659919
# [[467 134]
#  [ 33 354]]
# X shape: (4298, 22)
# Evaluating on dev set of 988 examples
# Accuracy: 0.827935222672
# [[454 147]
#  [ 23 364]]
# X shape: (4298, 22)
# Evaluating on dev set of 988 examples
# Accuracy: 0.865384615385
# [[500 101]
#  [ 32 355]]
# X shape: (4298, 22)
# Evaluating on dev set of 988 examples
# Accuracy: 0.865384615385
# [[499 102]
#  [ 31 356]]
# X shape: (4298, 22)
# Evaluating on dev set of 988 examples
# Accuracy: 0.863360323887
# [[499 102]
#  [ 33 354]]
# X shape: (4298, 22)
# Evaluating on dev set of 988 examples
# Accuracy: 0.862348178138
# [[499 102]
#  [ 34 353]]
# X shape: (4298, 22)
# Evaluating on dev set of 988 examples
# Accuracy: 0.864372469636
# [[501 100]
#  [ 34 353]]
# X shape: (4298, 22)
# Evaluating on dev set of 988 examples
# Accuracy: 0.864372469636
# [[501 100]
#  [ 34 353]]
# X shape: (4298, 22)
# Evaluating on dev set of 988 examples
# Accuracy: 0.862348178138
# [[500 101]
#  [ 35 352]]
# X shape: (4298, 22)
# Evaluating on dev set of 988 examples
# Accuracy: 0.862348178138
# [[500 101]
#  [ 35 352]]
# X shape: (4298, 22)
# Evaluating on dev set of 988 examples
# Accuracy: 0.862348178138
# [[500 101]
#  [ 35 352]]
# X shape: (4298, 22)
# Evaluating on dev set of 988 examples
# Accuracy: 0.861336032389
# [[499 102]
#  [ 35 352]]
# X shape: (7425, 22)
# Evaluating on dev set of 988 examples
# Accuracy: 0.849190283401
# [[491 110]
#  [ 39 348]]
# X shape: (7425, 22)
# Evaluating on dev set of 988 examples
# Accuracy: 0.821862348178
# [[452 149]
#  [ 27 360]]
# X shape: (7425, 22)
# Evaluating on dev set of 988 examples
# Accuracy: 0.84008097166
# [[482 119]
#  [ 39 348]]
# X shape: (7425, 22)
# Evaluating on dev set of 988 examples
# Accuracy: 0.84008097166
# [[476 125]
#  [ 33 354]]
# X shape: (7425, 22)
# Evaluating on dev set of 988 examples
# Accuracy: 0.843117408907
# [[483 118]
#  [ 37 350]]
# X shape: (7425, 22)
# Evaluating on dev set of 988 examples
# Accuracy: 0.845141700405
# [[483 118]
#  [ 35 352]]
# X shape: (7425, 22)
# Evaluating on dev set of 988 examples
# Accuracy: 0.845141700405
# [[484 117]
#  [ 36 351]]
# X shape: (7425, 22)
# Evaluating on dev set of 988 examples
# Accuracy: 0.844129554656
# [[483 118]
#  [ 36 351]]
# X shape: (7425, 22)
# Evaluating on dev set of 988 examples
# Accuracy: 0.844129554656
# [[483 118]
#  [ 36 351]]
# X shape: (7425, 22)
# Evaluating on dev set of 988 examples
# Accuracy: 0.844129554656
# [[483 118]
#  [ 36 351]]
# X shape: (7425, 22)
# Evaluating on dev set of 988 examples
# Accuracy: 0.844129554656
# [[483 118]
#  [ 36 351]]
# X shape: (7425, 22)
# Evaluating on dev set of 988 examples
# Accuracy: 0.844129554656
# [[483 118]
#  [ 36 351]]
# X shape: (37336, 22)
# Evaluating on dev set of 988 examples
# Accuracy: 0.862348178138
# [[505  96]
#  [ 40 347]]
# X shape: (37336, 22)
# Evaluating on dev set of 988 examples
# Accuracy: 0.854251012146
# [[492 109]
#  [ 35 352]]
# X shape: (37336, 22)
# Evaluating on dev set of 988 examples
# Accuracy: 0.861336032389
# [[504  97]
#  [ 40 347]]
# X shape: (37336, 22)
# Evaluating on dev set of 988 examples
# Accuracy: 0.86032388664
# [[503  98]
#  [ 40 347]]
# X shape: (37336, 22)
# Evaluating on dev set of 988 examples
# Accuracy: 0.86032388664
# [[503  98]
#  [ 40 347]]
# X shape: (37336, 22)
# Evaluating on dev set of 988 examples
# Accuracy: 0.859311740891
# [[502  99]
#  [ 40 347]]
# X shape: (37336, 22)
# Evaluating on dev set of 988 examples
# Accuracy: 0.858299595142
# [[501 100]
#  [ 40 347]]
# X shape: (37336, 22)
# Evaluating on dev set of 988 examples
# Accuracy: 0.859311740891
# [[502  99]
#  [ 40 347]]
# X shape: (37336, 22)
# Evaluating on dev set of 988 examples
# Accuracy: 0.858299595142
# [[501 100]
#  [ 40 347]]
# X shape: (37336, 22)
# Evaluating on dev set of 988 examples
# Accuracy: 0.859311740891
# [[502  99]
#  [ 40 347]]
# X shape: (37336, 22)
# Evaluating on dev set of 988 examples
# Accuracy: 0.858299595142
# [[501 100]
#  [ 40 347]]
# X shape: (37336, 22)
# Evaluating on dev set of 988 examples
# Accuracy: 0.859311740891
# [[502  99]
#  [ 40 347]]
# X shape: (4228, 44)
# Evaluating on dev set of 983 examples
# Accuracy: 0.821973550356
# [[486 115]
#  [ 60 322]]
# X shape: (4228, 44)
# Evaluating on dev set of 983 examples
# Accuracy: 0.81485249237
# [[466 135]
#  [ 47 335]]
# X shape: (4228, 44)
# Evaluating on dev set of 983 examples
# Accuracy: 0.810783316378
# [[450 151]
#  [ 35 347]]
# X shape: (4228, 44)
# Evaluating on dev set of 983 examples
# Accuracy: 0.781281790437
# [[414 187]
#  [ 28 354]]
# X shape: (4228, 44)
# Evaluating on dev set of 983 examples
# Accuracy: 0.703967446592
# [[332 269]
#  [ 22 360]]
# X shape: (4228, 44)
# Evaluating on dev set of 983 examples
# Accuracy: 0.693794506612
# [[322 279]
#  [ 22 360]]
# X shape: (4228, 44)
# Evaluating on dev set of 983 examples
# Accuracy: 0.668362156663
# [[296 305]
#  [ 21 361]]
# X shape: (4228, 44)
# Evaluating on dev set of 983 examples
# Accuracy: 0.668362156663
# [[295 306]
#  [ 20 362]]
# X shape: (4228, 44)
# Evaluating on dev set of 983 examples
# Accuracy: 0.663275686673
# [[289 312]
#  [ 19 363]]
# X shape: (4228, 44)
# Evaluating on dev set of 983 examples
# Accuracy: 0.66022380468
# [[287 314]
#  [ 20 362]]
# X shape: (4228, 44)
# Evaluating on dev set of 983 examples
# Accuracy: 0.661241098678
# [[287 314]
#  [ 19 363]]
# X shape: (4228, 44)
# Evaluating on dev set of 983 examples
# Accuracy: 0.658189216684
# [[285 316]
#  [ 20 362]]
# X shape: (7326, 44)
# Evaluating on dev set of 983 examples
# Accuracy: 0.802644964395
# [[466 135]
#  [ 59 323]]
# X shape: (7326, 44)
# Evaluating on dev set of 983 examples
# Accuracy: 0.793489318413
# [[453 148]
#  [ 55 327]]
# X shape: (7326, 44)
# Evaluating on dev set of 983 examples
# Accuracy: 0.802644964395
# [[459 142]
#  [ 52 330]]
# X shape: (7326, 44)
# Evaluating on dev set of 983 examples
# Accuracy: 0.786368260427
# [[441 160]
#  [ 50 332]]
# X shape: (7326, 44)
# Evaluating on dev set of 983 examples
# Accuracy: 0.779247202442
# [[430 171]
#  [ 46 336]]
# X shape: (7326, 44)
# Evaluating on dev set of 983 examples
# Accuracy: 0.772126144456
# [[424 177]
#  [ 47 335]]
# X shape: (7326, 44)
# Evaluating on dev set of 983 examples
# Accuracy: 0.77009155646
# [[421 180]
#  [ 46 336]]
# X shape: (7326, 44)
# Evaluating on dev set of 983 examples
# Accuracy: 0.77009155646
# [[421 180]
#  [ 46 336]]
# X shape: (7326, 44)
# Evaluating on dev set of 983 examples
# Accuracy: 0.769074262462
# [[420 181]
#  [ 46 336]]
# X shape: (7326, 44)
# Evaluating on dev set of 983 examples
# Accuracy: 0.768056968464
# [[419 182]
#  [ 46 336]]
# X shape: (7326, 44)
# Evaluating on dev set of 983 examples
# Accuracy: 0.769074262462
# [[420 181]
#  [ 46 336]]
# X shape: (7326, 44)
# Evaluating on dev set of 983 examples
# Accuracy: 0.763987792472
# [[415 186]
#  [ 46 336]]
# X shape: (36791, 44)
# Evaluating on dev set of 983 examples
# Accuracy: 0.834181078332
# [[496 105]
#  [ 58 324]]
# X shape: (36791, 44)
# Evaluating on dev set of 983 examples
# Accuracy: 0.829094608342
# [[493 108]
#  [ 60 322]]
# X shape: (36791, 44)
# Evaluating on dev set of 983 examples
# Accuracy: 0.826042726348
# [[483 118]
#  [ 53 329]]
# X shape: (36791, 44)
# Evaluating on dev set of 983 examples
# Accuracy: 0.826042726348
# [[481 120]
#  [ 51 331]]
# X shape: (36791, 44)
# Evaluating on dev set of 983 examples
# Accuracy: 0.824008138352
# [[479 122]
#  [ 51 331]]
# X shape: (36791, 44)
# Evaluating on dev set of 983 examples
# Accuracy: 0.824008138352
# [[479 122]
#  [ 51 331]]
# X shape: (36791, 44)
# Evaluating on dev set of 983 examples
# Accuracy: 0.821973550356
# [[477 124]
#  [ 51 331]]
# X shape: (36791, 44)
# Evaluating on dev set of 983 examples
# Accuracy: 0.818921668362
# [[474 127]
#  [ 51 331]]
# X shape: (36791, 44)
# Evaluating on dev set of 983 examples
# Accuracy: 0.821973550356
# [[477 124]
#  [ 51 331]]
# X shape: (36791, 44)
# Evaluating on dev set of 983 examples
# Accuracy: 0.818921668362
# [[474 127]
#  [ 51 331]]
# X shape: (36791, 44)
# Evaluating on dev set of 983 examples
# Accuracy: 0.821973550356
# [[477 124]
#  [ 51 331]]
# X shape: (36791, 44)
# Evaluating on dev set of 983 examples
# Accuracy: 0.81485249237
# [[472 129]
#  [ 53 329]]
# X shape: (4228, 22)
# Evaluating on dev set of 983 examples
# Accuracy: 0.807731434385
# [[453 148]
#  [ 41 341]]
# X shape: (4228, 22)
# Evaluating on dev set of 983 examples
# Accuracy: 0.794506612411
# [[427 174]
#  [ 28 354]]
# X shape: (4228, 22)
# Evaluating on dev set of 983 examples
# Accuracy: 0.842319430315
# [[481 120]
#  [ 35 347]]
# X shape: (4228, 22)
# Evaluating on dev set of 983 examples
# Accuracy: 0.839267548321
# [[478 123]
#  [ 35 347]]
# X shape: (4228, 22)
# Evaluating on dev set of 983 examples
# Accuracy: 0.841302136317
# [[481 120]
#  [ 36 346]]
# X shape: (4228, 22)
# Evaluating on dev set of 983 examples
# Accuracy: 0.839267548321
# [[481 120]
#  [ 38 344]]
# X shape: (4228, 22)
# Evaluating on dev set of 983 examples
# Accuracy: 0.840284842319
# [[481 120]
#  [ 37 345]]
# X shape: (4228, 22)
# Evaluating on dev set of 983 examples
# Accuracy: 0.840284842319
# [[481 120]
#  [ 37 345]]
# X shape: (4228, 22)
# Evaluating on dev set of 983 examples
# Accuracy: 0.840284842319
# [[481 120]
#  [ 37 345]]
# X shape: (4228, 22)
# Evaluating on dev set of 983 examples
# Accuracy: 0.840284842319
# [[481 120]
#  [ 37 345]]
# X shape: (4228, 22)
# Evaluating on dev set of 983 examples
# Accuracy: 0.840284842319
# [[481 120]
#  [ 37 345]]
# X shape: (4228, 22)
# Evaluating on dev set of 983 examples
# Accuracy: 0.840284842319
# [[481 120]
#  [ 37 345]]
# X shape: (7326, 22)
# Evaluating on dev set of 983 examples
# Accuracy: 0.804679552391
# [[456 145]
#  [ 47 335]]
# X shape: (7326, 22)
# Evaluating on dev set of 983 examples
# Accuracy: 0.785350966429
# [[428 173]
#  [ 38 344]]
# X shape: (7326, 22)
# Evaluating on dev set of 983 examples
# Accuracy: 0.799593082401
# [[448 153]
#  [ 44 338]]
# X shape: (7326, 22)
# Evaluating on dev set of 983 examples
# Accuracy: 0.800610376399
# [[447 154]
#  [ 42 340]]
# X shape: (7326, 22)
# Evaluating on dev set of 983 examples
# Accuracy: 0.800610376399
# [[449 152]
#  [ 44 338]]
# X shape: (7326, 22)
# Evaluating on dev set of 983 examples
# Accuracy: 0.800610376399
# [[449 152]
#  [ 44 338]]
# X shape: (7326, 22)
# Evaluating on dev set of 983 examples
# Accuracy: 0.800610376399
# [[449 152]
#  [ 44 338]]
# X shape: (7326, 22)
# Evaluating on dev set of 983 examples
# Accuracy: 0.800610376399
# [[449 152]
#  [ 44 338]]
# X shape: (7326, 22)
# Evaluating on dev set of 983 examples
# Accuracy: 0.800610376399
# [[449 152]
#  [ 44 338]]
# X shape: (7326, 22)
# Evaluating on dev set of 983 examples
# Accuracy: 0.800610376399
# [[449 152]
#  [ 44 338]]
# X shape: (7326, 22)
# Evaluating on dev set of 983 examples
# Accuracy: 0.800610376399
# [[449 152]
#  [ 44 338]]
# X shape: (7326, 22)
# Evaluating on dev set of 983 examples
# Accuracy: 0.800610376399
# [[449 152]
#  [ 44 338]]
# X shape: (36791, 22)
# Evaluating on dev set of 983 examples
# Accuracy: 0.834181078332
# [[488 113]
#  [ 50 332]]
# X shape: (36791, 22)
# Evaluating on dev set of 983 examples
# Accuracy: 0.827060020346
# [[477 124]
#  [ 46 336]]
# X shape: (36791, 22)
# Evaluating on dev set of 983 examples
# Accuracy: 0.833163784334
# [[485 116]
#  [ 48 334]]
# X shape: (36791, 22)
# Evaluating on dev set of 983 examples
# Accuracy: 0.832146490336
# [[483 118]
#  [ 47 335]]
# X shape: (36791, 22)
# Evaluating on dev set of 983 examples
# Accuracy: 0.832146490336
# [[484 117]
#  [ 48 334]]
# X shape: (36791, 22)
# Evaluating on dev set of 983 examples
# Accuracy: 0.829094608342
# [[481 120]
#  [ 48 334]]
# X shape: (36791, 22)
# Evaluating on dev set of 983 examples
# Accuracy: 0.828077314344
# [[480 121]
#  [ 48 334]]
# X shape: (36791, 22)
# Evaluating on dev set of 983 examples
# Accuracy: 0.828077314344
# [[480 121]
#  [ 48 334]]
# X shape: (36791, 22)
# Evaluating on dev set of 983 examples
# Accuracy: 0.828077314344
# [[480 121]
#  [ 48 334]]
# X shape: (36791, 22)
# Evaluating on dev set of 983 examples
# Accuracy: 0.828077314344
# [[480 121]
#  [ 48 334]]
# X shape: (36791, 22)
# Evaluating on dev set of 983 examples
# Accuracy: 0.828077314344
# [[480 121]
#  [ 48 334]]
# X shape: (36791, 22)
# Evaluating on dev set of 983 examples
# Accuracy: 0.828077314344
# [[480 121]
#  [ 48 334]]
# X shape: (4236, 44)
# Evaluating on dev set of 968 examples
# Accuracy: 0.79958677686
# [[466 119]
#  [ 75 308]]
# X shape: (4236, 44)
# Evaluating on dev set of 968 examples
# Accuracy: 0.796487603306
# [[441 144]
#  [ 53 330]]
# X shape: (4236, 44)
# Evaluating on dev set of 968 examples
# Accuracy: 0.762396694215
# [[397 188]
#  [ 42 341]]
# X shape: (4236, 44)
# Evaluating on dev set of 968 examples
# Accuracy: 0.726239669421
# [[352 233]
#  [ 32 351]]
# X shape: (4236, 44)
# Evaluating on dev set of 968 examples
# Accuracy: 0.638429752066
# [[259 326]
#  [ 24 359]]
# X shape: (4236, 44)
# Evaluating on dev set of 968 examples
# Accuracy: 0.625
# [[247 338]
#  [ 25 358]]
# X shape: (4236, 44)
# Evaluating on dev set of 968 examples
# Accuracy: 0.605371900826
# [[226 359]
#  [ 23 360]]
# X shape: (4236, 44)
# Evaluating on dev set of 968 examples
# Accuracy: 0.605371900826
# [[226 359]
#  [ 23 360]]
# X shape: (4236, 44)
# Evaluating on dev set of 968 examples
# Accuracy: 0.601239669421
# [[222 363]
#  [ 23 360]]
# X shape: (4236, 44)
# Evaluating on dev set of 968 examples
# Accuracy: 0.601239669421
# [[222 363]
#  [ 23 360]]
# X shape: (4236, 44)
# Evaluating on dev set of 968 examples
# Accuracy: 0.601239669421
# [[222 363]
#  [ 23 360]]
# X shape: (4236, 44)
# Evaluating on dev set of 968 examples
# Accuracy: 0.601239669421
# [[222 363]
#  [ 23 360]]
# X shape: (7360, 44)
# Evaluating on dev set of 968 examples
# Accuracy: 0.797520661157
# [[465 120]
#  [ 76 307]]
# X shape: (7360, 44)
# Evaluating on dev set of 968 examples
# Accuracy: 0.794421487603
# [[451 134]
#  [ 65 318]]
# X shape: (7360, 44)
# Evaluating on dev set of 968 examples
# Accuracy: 0.790289256198
# [[444 141]
#  [ 62 321]]
# X shape: (7360, 44)
# Evaluating on dev set of 968 examples
# Accuracy: 0.76652892562
# [[419 166]
#  [ 60 323]]
# X shape: (7360, 44)
# Evaluating on dev set of 968 examples
# Accuracy: 0.761363636364
# [[410 175]
#  [ 56 327]]
# X shape: (7360, 44)
# Evaluating on dev set of 968 examples
# Accuracy: 0.757231404959
# [[407 178]
#  [ 57 326]]
# X shape: (7360, 44)
# Evaluating on dev set of 968 examples
# Accuracy: 0.744834710744
# [[394 191]
#  [ 56 327]]
# X shape: (7360, 44)
# Evaluating on dev set of 968 examples
# Accuracy: 0.744834710744
# [[394 191]
#  [ 56 327]]
# X shape: (7360, 44)
# Evaluating on dev set of 968 examples
# Accuracy: 0.742768595041
# [[392 193]
#  [ 56 327]]
# X shape: (7360, 44)
# Evaluating on dev set of 968 examples
# Accuracy: 0.743801652893
# [[391 194]
#  [ 54 329]]
# X shape: (7360, 44)
# Evaluating on dev set of 968 examples
# Accuracy: 0.74173553719
# [[391 194]
#  [ 56 327]]
# X shape: (7360, 44)
# Evaluating on dev set of 968 examples
# Accuracy: 0.743801652893
# [[391 194]
#  [ 54 329]]
# X shape: (36751, 44)
# Evaluating on dev set of 968 examples
# Accuracy: 0.818181818182
# [[478 107]
#  [ 69 314]]
# X shape: (36751, 44)
# Evaluating on dev set of 968 examples
# Accuracy: 0.817148760331
# [[476 109]
#  [ 68 315]]
# X shape: (36751, 44)
# Evaluating on dev set of 968 examples
# Accuracy: 0.813016528926
# [[463 122]
#  [ 59 324]]
# X shape: (36751, 44)
# Evaluating on dev set of 968 examples
# Accuracy: 0.814049586777
# [[462 123]
#  [ 57 326]]
# X shape: (36751, 44)
# Evaluating on dev set of 968 examples
# Accuracy: 0.810950413223
# [[459 126]
#  [ 57 326]]
# X shape: (36751, 44)
# Evaluating on dev set of 968 examples
# Accuracy: 0.810950413223
# [[459 126]
#  [ 57 326]]
# X shape: (36751, 44)
# Evaluating on dev set of 968 examples
# Accuracy: 0.808884297521
# [[458 127]
#  [ 58 325]]
# X shape: (36751, 44)
# Evaluating on dev set of 968 examples
# Accuracy: 0.805785123967
# [[455 130]
#  [ 58 325]]
# X shape: (36751, 44)
# Evaluating on dev set of 968 examples
# Accuracy: 0.808884297521
# [[458 127]
#  [ 58 325]]
# X shape: (36751, 44)
# Evaluating on dev set of 968 examples
# Accuracy: 0.805785123967
# [[455 130]
#  [ 58 325]]
# X shape: (36751, 44)
# Evaluating on dev set of 968 examples
# Accuracy: 0.805785123967
# [[455 130]
#  [ 58 325]]
# X shape: (36751, 44)
# Evaluating on dev set of 968 examples
# Accuracy: 0.805785123967
# [[455 130]
#  [ 58 325]]
# X shape: (4236, 22)
# Evaluating on dev set of 968 examples
# Accuracy: 0.786157024793
# [[428 157]
#  [ 50 333]]
# X shape: (4236, 22)
# Evaluating on dev set of 968 examples
# Accuracy: 0.77479338843
# [[404 181]
#  [ 37 346]]
# X shape: (4236, 22)
# Evaluating on dev set of 968 examples
# Accuracy: 0.807851239669
# [[445 140]
#  [ 46 337]]
# X shape: (4236, 22)
# Evaluating on dev set of 968 examples
# Accuracy: 0.803719008264
# [[437 148]
#  [ 42 341]]
# X shape: (4236, 22)
# Evaluating on dev set of 968 examples
# Accuracy: 0.813016528926
# [[448 137]
#  [ 44 339]]
# X shape: (4236, 22)
# Evaluating on dev set of 968 examples
# Accuracy: 0.808884297521
# [[442 143]
#  [ 42 341]]
# X shape: (4236, 22)
# Evaluating on dev set of 968 examples
# Accuracy: 0.809917355372
# [[442 143]
#  [ 41 342]]
# X shape: (4236, 22)
# Evaluating on dev set of 968 examples
# Accuracy: 0.810950413223
# [[443 142]
#  [ 41 342]]
# X shape: (4236, 22)
# Evaluating on dev set of 968 examples
# Accuracy: 0.809917355372
# [[442 143]
#  [ 41 342]]
# X shape: (4236, 22)
# Evaluating on dev set of 968 examples
# Accuracy: 0.809917355372
# [[442 143]
#  [ 41 342]]
# X shape: (4236, 22)
# Evaluating on dev set of 968 examples
# Accuracy: 0.809917355372
# [[442 143]
#  [ 41 342]]
# X shape: (4236, 22)
# Evaluating on dev set of 968 examples
# Accuracy: 0.810950413223
# [[443 142]
#  [ 41 342]]
# X shape: (7360, 22)
# Evaluating on dev set of 968 examples
# Accuracy: 0.789256198347
# [[438 147]
#  [ 57 326]]
# X shape: (7360, 22)
# Evaluating on dev set of 968 examples
# Accuracy: 0.765495867769
# [[407 178]
#  [ 49 334]]
# X shape: (7360, 22)
# Evaluating on dev set of 968 examples
# Accuracy: 0.778925619835
# [[424 161]
#  [ 53 330]]
# X shape: (7360, 22)
# Evaluating on dev set of 968 examples
# Accuracy: 0.777892561983
# [[423 162]
#  [ 53 330]]
# X shape: (7360, 22)
# Evaluating on dev set of 968 examples
# Accuracy: 0.776859504132
# [[423 162]
#  [ 54 329]]
# X shape: (7360, 22)
# Evaluating on dev set of 968 examples
# Accuracy: 0.776859504132
# [[423 162]
#  [ 54 329]]
# X shape: (7360, 22)
# Evaluating on dev set of 968 examples
# Accuracy: 0.776859504132
# [[423 162]
#  [ 54 329]]
# X shape: (7360, 22)
# Evaluating on dev set of 968 examples
# Accuracy: 0.778925619835
# [[424 161]
#  [ 53 330]]
# X shape: (7360, 22)
# Evaluating on dev set of 968 examples
# Accuracy: 0.778925619835
# [[424 161]
#  [ 53 330]]
# X shape: (7360, 22)
# Evaluating on dev set of 968 examples
# Accuracy: 0.778925619835
# [[424 161]
#  [ 53 330]]
# X shape: (7360, 22)
# Evaluating on dev set of 968 examples
# Accuracy: 0.778925619835
# [[424 161]
#  [ 53 330]]
# X shape: (7360, 22)
# Evaluating on dev set of 968 examples
# Accuracy: 0.778925619835
# [[424 161]
#  [ 53 330]]
# X shape: (36751, 22)
# Evaluating on dev set of 968 examples
# Accuracy: 0.816115702479
# [[466 119]
#  [ 59 324]]
# X shape: (36751, 22)
# Evaluating on dev set of 968 examples
# Accuracy: 0.810950413223
# [[458 127]
#  [ 56 327]]
# X shape: (36751, 22)
# Evaluating on dev set of 968 examples
# Accuracy: 0.817148760331
# [[464 121]
#  [ 56 327]]
# X shape: (36751, 22)
# Evaluating on dev set of 968 examples
# Accuracy: 0.815082644628
# [[462 123]
#  [ 56 327]]
# X shape: (36751, 22)
# Evaluating on dev set of 968 examples
# Accuracy: 0.815082644628
# [[462 123]
#  [ 56 327]]
# X shape: (36751, 22)
# Evaluating on dev set of 968 examples
# Accuracy: 0.817148760331
# [[464 121]
#  [ 56 327]]
# X shape: (36751, 22)
# Evaluating on dev set of 968 examples
# Accuracy: 0.816115702479
# [[463 122]
#  [ 56 327]]
# X shape: (36751, 22)
# Evaluating on dev set of 968 examples
# Accuracy: 0.816115702479
# [[463 122]
#  [ 56 327]]
# X shape: (36751, 22)
# Evaluating on dev set of 968 examples
# Accuracy: 0.816115702479
# [[463 122]
#  [ 56 327]]
# X shape: (36751, 22)
# Evaluating on dev set of 968 examples
# Accuracy: 0.816115702479
# [[463 122]
#  [ 56 327]]
# X shape: (36751, 22)
# Evaluating on dev set of 968 examples
# Accuracy: 0.816115702479
# [[463 122]
#  [ 56 327]]
# X shape: (36751, 22)
# Evaluating on dev set of 968 examples
# Accuracy: 0.816115702479
# [[463 122]
#  [ 56 327]]
# X shape: (4124, 44)
# Evaluating on dev set of 954 examples
# Accuracy: 0.792452830189
# [[474 106]
#  [ 92 282]]
# X shape: (4124, 44)
# Evaluating on dev set of 954 examples
# Accuracy: 0.785115303983
# [[440 140]
#  [ 65 309]]
# X shape: (4124, 44)
# Evaluating on dev set of 954 examples
# Accuracy: 0.720125786164
# [[346 234]
#  [ 33 341]]
# X shape: (4124, 44)
# Evaluating on dev set of 954 examples
# Accuracy: 0.657232704403
# [[285 295]
#  [ 32 342]]
# X shape: (4124, 44)
# Evaluating on dev set of 954 examples
# Accuracy: 0.567085953878
# [[195 385]
#  [ 28 346]]
# X shape: (4124, 44)
# Evaluating on dev set of 954 examples
# Accuracy: 0.562893081761
# [[192 388]
#  [ 29 345]]
# X shape: (4124, 44)
# Evaluating on dev set of 954 examples
# Accuracy: 0.553459119497
# [[183 397]
#  [ 29 345]]
# X shape: (4124, 44)
# Evaluating on dev set of 954 examples
# Accuracy: 0.551362683438
# [[182 398]
#  [ 30 344]]
# X shape: (4124, 44)
# Evaluating on dev set of 954 examples
# Accuracy: 0.550314465409
# [[181 399]
#  [ 30 344]]
# X shape: (4124, 44)
# Evaluating on dev set of 954 examples
# Accuracy: 0.550314465409
# [[181 399]
#  [ 30 344]]
# X shape: (4124, 44)
# Evaluating on dev set of 954 examples
# Accuracy: 0.549266247379
# [[180 400]
#  [ 30 344]]
# X shape: (4124, 44)
# Evaluating on dev set of 954 examples
# Accuracy: 0.550314465409
# [[181 399]
#  [ 30 344]]
# X shape: (7148, 44)
# Evaluating on dev set of 954 examples
# Accuracy: 0.750524109015
# [[451 129]
#  [109 265]]
# X shape: (7148, 44)
# Evaluating on dev set of 954 examples
# Accuracy: 0.740041928721
# [[424 156]
#  [ 92 282]]
# X shape: (7148, 44)
# Evaluating on dev set of 954 examples
# Accuracy: 0.740041928721
# [[414 166]
#  [ 82 292]]
# X shape: (7148, 44)
# Evaluating on dev set of 954 examples
# Accuracy: 0.718029350105
# [[388 192]
#  [ 77 297]]
# X shape: (7148, 44)
# Evaluating on dev set of 954 examples
# Accuracy: 0.701257861635
# [[366 214]
#  [ 71 303]]
# X shape: (7148, 44)
# Evaluating on dev set of 954 examples
# Accuracy: 0.694968553459
# [[359 221]
#  [ 70 304]]
# X shape: (7148, 44)
# Evaluating on dev set of 954 examples
# Accuracy: 0.684486373166
# [[348 232]
#  [ 69 305]]
# X shape: (7148, 44)
# Evaluating on dev set of 954 examples
# Accuracy: 0.683438155136
# [[347 233]
#  [ 69 305]]
# X shape: (7148, 44)
# Evaluating on dev set of 954 examples
# Accuracy: 0.681341719078
# [[345 235]
#  [ 69 305]]
# X shape: (7148, 44)
# Evaluating on dev set of 954 examples
# Accuracy: 0.681341719078
# [[345 235]
#  [ 69 305]]
# X shape: (7148, 44)
# Evaluating on dev set of 954 examples
# Accuracy: 0.681341719078
# [[345 235]
#  [ 69 305]]
# X shape: (7148, 44)
# Evaluating on dev set of 954 examples
# Accuracy: 0.681341719078
# [[345 235]
#  [ 69 305]]
# X shape: (36002, 44)
# Evaluating on dev set of 954 examples
# Accuracy: 0.77358490566
# [[471 109]
#  [107 267]]
# X shape: (36002, 44)
# Evaluating on dev set of 954 examples
# Accuracy: 0.77358490566
# [[459 121]
#  [ 95 279]]
# X shape: (36002, 44)
# Evaluating on dev set of 954 examples
# Accuracy: 0.768343815514
# [[446 134]
#  [ 87 287]]
# X shape: (36002, 44)
# Evaluating on dev set of 954 examples
# Accuracy: 0.767295597484
# [[445 135]
#  [ 87 287]]
# X shape: (36002, 44)
# Evaluating on dev set of 954 examples
# Accuracy: 0.763102725367
# [[444 136]
#  [ 90 284]]
# X shape: (36002, 44)
# Evaluating on dev set of 954 examples
# Accuracy: 0.765199161426
# [[444 136]
#  [ 88 286]]
# X shape: (36002, 44)
# Evaluating on dev set of 954 examples
# Accuracy: 0.759958071279
# [[440 140]
#  [ 89 285]]
# X shape: (36002, 44)
# Evaluating on dev set of 954 examples
# Accuracy: 0.758909853249
# [[439 141]
#  [ 89 285]]
# X shape: (36002, 44)
# Evaluating on dev set of 954 examples
# Accuracy: 0.759958071279
# [[440 140]
#  [ 89 285]]
# X shape: (36002, 44)
# Evaluating on dev set of 954 examples
# Accuracy: 0.759958071279
# [[439 141]
#  [ 88 286]]
# X shape: (36002, 44)
# Evaluating on dev set of 954 examples
# Accuracy: 0.758909853249
# [[439 141]
#  [ 89 285]]
# X shape: (36002, 44)
# Evaluating on dev set of 954 examples
# Accuracy: 0.759958071279
# [[439 141]
#  [ 88 286]]
# X shape: (4124, 22)
# Evaluating on dev set of 954 examples
# Accuracy: 0.751572327044
# [[416 164]
#  [ 73 301]]
# X shape: (4124, 22)
# Evaluating on dev set of 954 examples
# Accuracy: 0.752620545073
# [[392 188]
#  [ 48 326]]
# X shape: (4124, 22)
# Evaluating on dev set of 954 examples
# Accuracy: 0.769392033543
# [[408 172]
#  [ 48 326]]
# X shape: (4124, 22)
# Evaluating on dev set of 954 examples
# Accuracy: 0.772536687631
# [[410 170]
#  [ 47 327]]
# X shape: (4124, 22)
# Evaluating on dev set of 954 examples
# Accuracy: 0.781970649895
# [[418 162]
#  [ 46 328]]
# X shape: (4124, 22)
# Evaluating on dev set of 954 examples
# Accuracy: 0.783018867925
# [[420 160]
#  [ 47 327]]
# X shape: (4124, 22)
# Evaluating on dev set of 954 examples
# Accuracy: 0.780922431866
# [[417 163]
#  [ 46 328]]
# X shape: (4124, 22)
# Evaluating on dev set of 954 examples
# Accuracy: 0.780922431866
# [[417 163]
#  [ 46 328]]
# X shape: (4124, 22)
# Evaluating on dev set of 954 examples
# Accuracy: 0.781970649895
# [[418 162]
#  [ 46 328]]
# X shape: (4124, 22)
# Evaluating on dev set of 954 examples
# Accuracy: 0.781970649895
# [[418 162]
#  [ 46 328]]
# X shape: (4124, 22)
# Evaluating on dev set of 954 examples
# Accuracy: 0.781970649895
# [[418 162]
#  [ 46 328]]
# X shape: (4124, 22)
# Evaluating on dev set of 954 examples
# Accuracy: 0.781970649895
# [[418 162]
#  [ 46 328]]
# X shape: (7148, 22)
# Evaluating on dev set of 954 examples
# Accuracy: 0.738993710692
# [[410 170]
#  [ 79 295]]
# X shape: (7148, 22)
# Evaluating on dev set of 954 examples
# Accuracy: 0.718029350105
# [[386 194]
#  [ 75 299]]
# X shape: (7148, 22)
# Evaluating on dev set of 954 examples
# Accuracy: 0.72641509434
# [[396 184]
#  [ 77 297]]
# X shape: (7148, 22)
# Evaluating on dev set of 954 examples
# Accuracy: 0.724318658281
# [[392 188]
#  [ 75 299]]
# X shape: (7148, 22)
# Evaluating on dev set of 954 examples
# Accuracy: 0.724318658281
# [[393 187]
#  [ 76 298]]
# X shape: (7148, 22)
# Evaluating on dev set of 954 examples
# Accuracy: 0.722222222222
# [[391 189]
#  [ 76 298]]
# X shape: (7148, 22)
# Evaluating on dev set of 954 examples
# Accuracy: 0.722222222222
# [[391 189]
#  [ 76 298]]
# X shape: (7148, 22)
# Evaluating on dev set of 954 examples
# Accuracy: 0.723270440252
# [[392 188]
#  [ 76 298]]
# X shape: (7148, 22)
# Evaluating on dev set of 954 examples
# Accuracy: 0.723270440252
# [[392 188]
#  [ 76 298]]
# X shape: (7148, 22)
# Evaluating on dev set of 954 examples
# Accuracy: 0.722222222222
# [[391 189]
#  [ 76 298]]
# X shape: (7148, 22)
# Evaluating on dev set of 954 examples
# Accuracy: 0.723270440252
# [[392 188]
#  [ 76 298]]
# X shape: (7148, 22)
# Evaluating on dev set of 954 examples
# Accuracy: 0.722222222222
# [[391 189]
#  [ 76 298]]
# X shape: (36002, 22)
# Evaluating on dev set of 954 examples
# Accuracy: 0.770440251572
# [[449 131]
#  [ 88 286]]
# X shape: (36002, 22)
# Evaluating on dev set of 954 examples
# Accuracy: 0.765199161426
# [[444 136]
#  [ 88 286]]
# X shape: (36002, 22)
# Evaluating on dev set of 954 examples
# Accuracy: 0.767295597484
# [[449 131]
#  [ 91 283]]
# X shape: (36002, 22)
# Evaluating on dev set of 954 examples
# Accuracy: 0.764150943396
# [[446 134]
#  [ 91 283]]
# X shape: (36002, 22)
# Evaluating on dev set of 954 examples
# Accuracy: 0.764150943396
# [[446 134]
#  [ 91 283]]
# X shape: (36002, 22)
# Evaluating on dev set of 954 examples
# Accuracy: 0.763102725367
# [[445 135]
#  [ 91 283]]
# X shape: (36002, 22)
# Evaluating on dev set of 954 examples
# Accuracy: 0.762054507338
# [[444 136]
#  [ 91 283]]
# X shape: (36002, 22)
# Evaluating on dev set of 954 examples
# Accuracy: 0.762054507338
# [[444 136]
#  [ 91 283]]
# X shape: (36002, 22)
# Evaluating on dev set of 954 examples
# Accuracy: 0.762054507338
# [[444 136]
#  [ 91 283]]
# X shape: (36002, 22)
# Evaluating on dev set of 954 examples
# Accuracy: 0.762054507338
# [[444 136]
#  [ 91 283]]
# X shape: (36002, 22)
# Evaluating on dev set of 954 examples
# Accuracy: 0.762054507338
# [[444 136]
#  [ 91 283]]
# X shape: (36002, 22)
# Evaluating on dev set of 954 examples
# Accuracy: 0.762054507338
# [[444 136]
#  [ 91 283]]
# X shape: (4040, 44)
# Evaluating on dev set of 942 examples
# Accuracy: 0.784501061571
# [[474 102]
#  [101 265]]
# X shape: (4040, 44)
# Evaluating on dev set of 942 examples
# Accuracy: 0.771762208068
# [[419 157]
#  [ 58 308]]
# X shape: (4040, 44)
# Evaluating on dev set of 942 examples
# Accuracy: 0.668789808917
# [[296 280]
#  [ 32 334]]
# X shape: (4040, 44)
# Evaluating on dev set of 942 examples
# Accuracy: 0.577494692144
# [[208 368]
#  [ 30 336]]
# X shape: (4040, 44)
# Evaluating on dev set of 942 examples
# Accuracy: 0.563694267516
# [[177 399]
#  [ 12 354]]
# X shape: (4040, 44)
# Evaluating on dev set of 942 examples
# Accuracy: 0.563694267516
# [[177 399]
#  [ 12 354]]
# X shape: (4040, 44)
# Evaluating on dev set of 942 examples
# Accuracy: 0.557324840764
# [[171 405]
#  [ 12 354]]
# X shape: (4040, 44)
# Evaluating on dev set of 942 examples
# Accuracy: 0.556263269639
# [[170 406]
#  [ 12 354]]
# X shape: (4040, 44)
# Evaluating on dev set of 942 examples
# Accuracy: 0.556263269639
# [[169 407]
#  [ 11 355]]
# X shape: (4040, 44)
# Evaluating on dev set of 942 examples
# Accuracy: 0.556263269639
# [[169 407]
#  [ 11 355]]
# X shape: (4040, 44)
# Evaluating on dev set of 942 examples
# Accuracy: 0.556263269639
# [[169 407]
#  [ 11 355]]
# X shape: (4040, 44)
# Evaluating on dev set of 942 examples
# Accuracy: 0.556263269639
# [[169 407]
#  [ 11 355]]
# X shape: (6998, 44)
# Evaluating on dev set of 942 examples
# Accuracy: 0.705944798301
# [[453 123]
#  [154 212]]
# X shape: (6998, 44)
# Evaluating on dev set of 942 examples
# Accuracy: 0.726114649682
# [[421 155]
#  [103 263]]
# X shape: (6998, 44)
# Evaluating on dev set of 942 examples
# Accuracy: 0.687898089172
# [[367 209]
#  [ 85 281]]
# X shape: (6998, 44)
# Evaluating on dev set of 942 examples
# Accuracy: 0.683651804671
# [[344 232]
#  [ 66 300]]
# X shape: (6998, 44)
# Evaluating on dev set of 942 examples
# Accuracy: 0.64118895966
# [[294 282]
#  [ 56 310]]
# X shape: (6998, 44)
# Evaluating on dev set of 942 examples
# Accuracy: 0.631634819533
# [[283 293]
#  [ 54 312]]
# X shape: (6998, 44)
# Evaluating on dev set of 942 examples
# Accuracy: 0.608280254777
# [[255 321]
#  [ 48 318]]
# X shape: (6998, 44)
# Evaluating on dev set of 942 examples
# Accuracy: 0.611464968153
# [[258 318]
#  [ 48 318]]
# X shape: (6998, 44)
# Evaluating on dev set of 942 examples
# Accuracy: 0.607218683652
# [[253 323]
#  [ 47 319]]
# X shape: (6998, 44)
# Evaluating on dev set of 942 examples
# Accuracy: 0.607218683652
# [[253 323]
#  [ 47 319]]
# X shape: (6998, 44)
# Evaluating on dev set of 942 examples
# Accuracy: 0.606157112527
# [[253 323]
#  [ 48 318]]
# X shape: (6998, 44)
# Evaluating on dev set of 942 examples
# Accuracy: 0.606157112527
# [[251 325]
#  [ 46 320]]
# X shape: (35208, 44)
# Evaluating on dev set of 942 examples
# Accuracy: 0.761146496815
# [[472 104]
#  [121 245]]
# X shape: (35208, 44)
# Evaluating on dev set of 942 examples
# Accuracy: 0.747346072187
# [[449 127]
#  [111 255]]
# X shape: (35208, 44)
# Evaluating on dev set of 942 examples
# Accuracy: 0.73991507431
# [[434 142]
#  [103 263]]
# X shape: (35208, 44)
# Evaluating on dev set of 942 examples
# Accuracy: 0.743099787686
# [[435 141]
#  [101 265]]
# X shape: (35208, 44)
# Evaluating on dev set of 942 examples
# Accuracy: 0.736730360934
# [[428 148]
#  [100 266]]
# X shape: (35208, 44)
# Evaluating on dev set of 942 examples
# Accuracy: 0.735668789809
# [[427 149]
#  [100 266]]
# X shape: (35208, 44)
# Evaluating on dev set of 942 examples
# Accuracy: 0.734607218684
# [[425 151]
#  [ 99 267]]
# X shape: (35208, 44)
# Evaluating on dev set of 942 examples
# Accuracy: 0.734607218684
# [[425 151]
#  [ 99 267]]
# X shape: (35208, 44)
# Evaluating on dev set of 942 examples
# Accuracy: 0.734607218684
# [[425 151]
#  [ 99 267]]
# X shape: (35208, 44)
# Evaluating on dev set of 942 examples
# Accuracy: 0.733545647558
# [[420 156]
#  [ 95 271]]
# X shape: (35208, 44)
# Evaluating on dev set of 942 examples
# Accuracy: 0.734607218684
# [[425 151]
#  [ 99 267]]
# X shape: (35208, 44)
# Evaluating on dev set of 942 examples
# Accuracy: 0.733545647558
# [[420 156]
#  [ 95 271]]
# X shape: (4040, 22)
# Evaluating on dev set of 942 examples
# Accuracy: 0.723991507431
# [[413 163]
#  [ 97 269]]
# X shape: (4040, 22)
# Evaluating on dev set of 942 examples
# Accuracy: 0.73991507431
# [[378 198]
#  [ 47 319]]
# X shape: (4040, 22)
# Evaluating on dev set of 942 examples
# Accuracy: 0.753715498938
# [[390 186]
#  [ 46 320]]
# X shape: (4040, 22)
# Evaluating on dev set of 942 examples
# Accuracy: 0.744161358811
# [[379 197]
#  [ 44 322]]
# X shape: (4040, 22)
# Evaluating on dev set of 942 examples
# Accuracy: 0.748407643312
# [[384 192]
#  [ 45 321]]
# X shape: (4040, 22)
# Evaluating on dev set of 942 examples
# Accuracy: 0.750530785563
# [[385 191]
#  [ 44 322]]
# X shape: (4040, 22)
# Evaluating on dev set of 942 examples
# Accuracy: 0.768577494692
# [[399 177]
#  [ 41 325]]
# X shape: (4040, 22)
# Evaluating on dev set of 942 examples
# Accuracy: 0.767515923567
# [[399 177]
#  [ 42 324]]
# X shape: (4040, 22)
# Evaluating on dev set of 942 examples
# Accuracy: 0.766454352442
# [[398 178]
#  [ 42 324]]
# X shape: (4040, 22)
# Evaluating on dev set of 942 examples
# Accuracy: 0.767515923567
# [[399 177]
#  [ 42 324]]
# X shape: (4040, 22)
# Evaluating on dev set of 942 examples
# Accuracy: 0.767515923567
# [[399 177]
#  [ 42 324]]
# X shape: (4040, 22)
# Evaluating on dev set of 942 examples
# Accuracy: 0.767515923567
# [[399 177]
#  [ 42 324]]
# X shape: (6998, 22)
# Evaluating on dev set of 942 examples
# Accuracy: 0.712314225053
# [[407 169]
#  [102 264]]
# X shape: (6998, 22)
# Evaluating on dev set of 942 examples
# Accuracy: 0.702760084926
# [[388 188]
#  [ 92 274]]
# X shape: (6998, 22)
# Evaluating on dev set of 942 examples
# Accuracy: 0.695329087049
# [[380 196]
#  [ 91 275]]
# X shape: (6998, 22)
# Evaluating on dev set of 942 examples
# Accuracy: 0.693205944798
# [[375 201]
#  [ 88 278]]
# X shape: (6998, 22)
# Evaluating on dev set of 942 examples
# Accuracy: 0.692144373673
# [[374 202]
#  [ 88 278]]
# X shape: (6998, 22)
# Evaluating on dev set of 942 examples
# Accuracy: 0.692144373673
# [[374 202]
#  [ 88 278]]
# X shape: (6998, 22)
# Evaluating on dev set of 942 examples
# Accuracy: 0.692144373673
# [[374 202]
#  [ 88 278]]
# X shape: (6998, 22)
# Evaluating on dev set of 942 examples
# Accuracy: 0.692144373673
# [[374 202]
#  [ 88 278]]
# X shape: (6998, 22)
# Evaluating on dev set of 942 examples
# Accuracy: 0.692144373673
# [[374 202]
#  [ 88 278]]
# X shape: (6998, 22)
# Evaluating on dev set of 942 examples
# Accuracy: 0.692144373673
# [[374 202]
#  [ 88 278]]
# X shape: (6998, 22)
# Evaluating on dev set of 942 examples
# Accuracy: 0.692144373673
# [[374 202]
#  [ 88 278]]
# X shape: (6998, 22)
# Evaluating on dev set of 942 examples
# Accuracy: 0.692144373673
# [[374 202]
#  [ 88 278]]
# X shape: (35208, 22)
# Evaluating on dev set of 942 examples
# Accuracy: 0.744161358811
# [[453 123]
#  [118 248]]
# X shape: (35208, 22)
# Evaluating on dev set of 942 examples
# Accuracy: 0.750530785563
# [[445 131]
#  [104 262]]
# X shape: (35208, 22)
# Evaluating on dev set of 942 examples
# Accuracy: 0.746284501062
# [[446 130]
#  [109 257]]
# X shape: (35208, 22)
# Evaluating on dev set of 942 examples
# Accuracy: 0.746284501062
# [[445 131]
#  [108 258]]
# X shape: (35208, 22)
# Evaluating on dev set of 942 examples
# Accuracy: 0.750530785563
# [[445 131]
#  [104 262]]
# X shape: (35208, 22)
# Evaluating on dev set of 942 examples
# Accuracy: 0.749469214437
# [[444 132]
#  [104 262]]
# X shape: (35208, 22)
# Evaluating on dev set of 942 examples
# Accuracy: 0.750530785563
# [[445 131]
#  [104 262]]
# X shape: (35208, 22)
# Evaluating on dev set of 942 examples
# Accuracy: 0.749469214437
# [[444 132]
#  [104 262]]
# X shape: (35208, 22)
# Evaluating on dev set of 942 examples
# Accuracy: 0.749469214437
# [[444 132]
#  [104 262]]
# X shape: (35208, 22)
# Evaluating on dev set of 942 examples
# Accuracy: 0.749469214437
# [[444 132]
#  [104 262]]
# X shape: (35208, 22)
# Evaluating on dev set of 942 examples
# Accuracy: 0.749469214437
# [[444 132]
#  [104 262]]
# X shape: (35208, 22)
# Evaluating on dev set of 942 examples
# Accuracy: 0.749469214437
# [[444 132]
#  [104 262]]

# %%
for target in target_vars:
    df_dict[target].to_csv(target+".csv")
